# %%
class Pegawai:
  def __init__(self, a, b, c, d):
    self.nama = a
    self.status = b
    self.tahun = c
    self.gaji = d

class Data:
  def __init__(self):
    self.data_dictionary = {}

  def tambah(self, pegawai):
    nama = pegawai.nama
    self.data_dictionary[nama] = pegawai

  def edit(self, cari, data_baru):
    for nama, data in self.data_dictionary.items():
      if nama == cari:
        data.status = data_baru["status"]
        data.tahun = data_baru["tahun"]
        data.gaji = data_baru["gaji"]

  def hapus(self, cari):
    hapus = []
    for nama in self.data_dictionary:
      if nama == cari:
        hapus.append(nama)

    for i in hapus:
      self.data_dictionary.pop(i)

  def tampil(self):
    print("Daftar Pegawai: ")
    no = 1
    for nama, data in self.data_dictionary.items():
      print(f"Data No {no}")
      print(f"Nama = {nama}")
      print(f"Status = {data.status}")
      print(f"Tahun = {data.tahun}")
      print(f"Gaji = {data.gaji}")
      no += 1

def menu():
  print("Selamat Datang di Sistem Informasi Pegawai")
  print("Silahkan Memilih Menu:")
  print("1. Tambah Pegawai")
  print("2. Edit Pegawai")
  print("3. Hapus Pegawai")
  print("4. Tampilkan Pegawai")

data = Data()

while True:
  menu()

  pilih = int(input("Pilih Menu: "))

  if pilih == 1:
    masuk = int(input("Tambah Berapa Data: "))
    no = 1
    for i in range(masuk):
      print(f"Data No {no}")
      nama = input("Masukan Nama: ")
      status = input("Masukan Status: ")
      tahun = int(input("Masukan Tahun: "))
      gaji = int(input("Masukan Gaji: "))

      data.tambah(Pegawai(nama, status, tahun, gaji))
      no += 1

  elif pilih == 2:
    data.tampil()

    nama = input("Masukan Nama: ")
    status = input("Masukan Status: ")
    tahun = int(input("Masukan Tahun: "))
    gaji = int(input("Masukan Gaji: "))

    data_baru = {"nama": nama, "status": status, "tahun": tahun, "gaji": gaji}
    data.edit(nama, data_baru)

  elif pilih == 3:
    data.tampil()
    nama = input("Masukan Nama Yang Ingin Dihapus: ")
    data.hapus(nama)

  elif pilih == 4:
    data.tampil()

  elif pilih == 5:
    break
# Out:
# Selamat Datang di Sistem Informasi Pegawai
# Silahkan Memilih Menu:
# 1. Tambah Pegawai
# 2. Edit Pegawai
# 3. Hapus Pegawai
# 4. Tampilkan Pegawai
# Pilih Menu: 1
# Tambah Berapa Data: 3
# Data No 1
# Masukan Nama: John Robert
# Masukan Status: Full Time
# Masukan Tahun: 2019
# Masukan Gaji: 150000
# Data No 2
# Masukan Nama: Ana Taro
# Masukan Status: Full Time
# Masukan Tahun: 2015
# Masukan Gaji: 160000
# Data No 3
# Masukan Nama: Sasa Nia
# Masukan Status: Part TIme
# Masukan Tahun: 2019
# Masukan Gaji: 40000
# Selamat Datang di Sistem Informasi Pegawai
# Silahkan Memilih Menu:
# 1. Tambah Pegawai
# 2. Edit Pegawai
# 3. Hapus Pegawai
# 4. Tampilkan Pegawai
# Pilih Menu: 3
# Daftar Pegawai:
# Data No 1
# Nama = John Robert
# Status = Full Time
# Tahun = 2019
# Gaji = 150000
# Data No 2
# Nama = Ana Taro
# Status = Full Time
# Tahun = 2015
# Gaji = 160000
# Data No 3
# Nama = Sasa Nia
# Status = Part TIme
# Tahun = 2019
# Gaji = 40000
# Masukan Nama Yang Ingin Dihapus: Sasa Nia
# Selamat Datang di Sistem Informasi Pegawai
# Silahkan Memilih Menu:
# 1. Tambah Pegawai
# 2. Edit Pegawai
# 3. Hapus Pegawai
# 4. Tampilkan Pegawai
# Pilih Menu: 4
# Daftar Pegawai:
# Data No 1
# Nama = John Robert
# Status = Full Time
# Tahun = 2019
# Gaji = 150000
# Data No 2
# Nama = Ana Taro
# Status = Full Time
# Tahun = 2015
# Gaji = 160000
# Selamat Datang di Sistem Informasi Pegawai
# Silahkan Memilih Menu:
# 1. Tambah Pegawai
# 2. Edit Pegawai
# 3. Hapus Pegawai
# 4. Tampilkan Pegawai
# Pilih Menu: 5
